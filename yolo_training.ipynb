# %% [markdown]
# <a href="https://colab.research.google.com/github/EsraCansu/Python/blob/main/yolo_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir('/content/drive/MyDrive/Yolo_training')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# data_image/  data.yaml  yolo_training.ipynb  yolo.zip

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 17516 (delta 6), reused 0 (delta 0), pack-reused 17497 (from 4)
# Receiving objects: 100% (17516/17516), 16.66 MiB | 16.20 MiB/s, done.
# Resolving deltas: 100% (11997/11997), done.

# %%
os.chdir('yolov5')

# %%
ls
# Out:
# benchmarks.py    data_image/  LICENSE          requirements.txt  val.py
# CITATION.cff     data.yaml    models/          segment/
# classify/        detect.py    pyproject.toml   train.py
# CONTRIBUTING.md  export.py    README.md        tutorial.ipynb
# data/            hubconf.py   README.zh-CN.md  utils/

# %%
### Install all required packages from requriments.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 37.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !cat data.yaml
# Out:
# train: data_image/train
# val: data_image/test
# nc: 1
# names: ['dart']

# %%
### **Training Yolo V5 Model**

# %%
# !python train.py --data data.yaml --weights yolov5s.pt --img 640 --batch-size 8 --name Model --epochs 50
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-07-15 19:46:15.511487: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752608775.830565    2094 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# Resume training model
# !python train.py --data data.yaml --weights runs/train/Model4/weights/best.pt --img 640 --batch size 8 --name model --epochs 50

# %%
### Export Model onnx file

# %%
# !ls '/content/drive/MyDrive/Yolo_training/yolov5'
# %cd '/content/drive/MyDrive/Yolo_training/yolov5'
# Out:
# benchmarks.py	 data_image  LICENSE	     README.zh-CN.md   tutorial.ipynb
# CITATION.cff	 data.yaml   models	     requirements.txt  utils
# classify	 detect.py   __pycache__     runs	       val.py
# CONTRIBUTING.md  export.py   pyproject.toml  segment	       yolov5s.pt
# data		 hubconf.py  README.md	     train.py
# /content

# %%
# !python export.py --weights runs/train/Model4/weights/best.pt --include onnx --simplify --opset 12
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/Model4/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=True, mlmodel=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CPU
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Yolo_training/yolov5/export.py", line 1547, in <module>
#     main(opt)
#   File "/content/drive/MyDrive/Yolo_training/yolov5/export.py", line 1542, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/Yolo_training/yolov5/export.py", line 1386, in run
# ...
